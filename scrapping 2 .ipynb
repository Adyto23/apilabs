# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# 2. find url and store it in a variable
url = "https://en.wikipedia.org/wiki/Python"

# %%
response = requests.get(url)

# %%
response.status_code # 200 status code means OK!
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup.select("li:nth-child(1) > a ")

#mw-content-text > div.mw-parser-output > ul:nth-child(2) > li:nth-child(1) > a
# Out:
# [<a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a>,
#  <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Python" title="You are encouraged to create an account and log in; however, it is not mandatory"><span>Create account</span></a>,
#  <a href="/w/index.php?title=Special:CreateAccount&amp;returnto=Python" title="You are encouraged to create an account and log in; however, it is not mandatory"><span class="mw-ui-icon mw-ui-icon-userAdd mw-ui-icon-wikimedia-userAdd"></span> <span>Create account</span></a>,
#  <a accesskey="y" href="/wiki/Special:MyContributions" title="A list of edits made from this IP address [y]"><span>Contributions</span></a>,
#  <a class="vector-toc-link" href="#">
#  <div class="vector-toc-text">(Top)</div>
#  </a>,
# ...

# %%
soup.select("a")
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
# ...

# %%
links=[]
num_iter = len(soup.select("a"))
tClist = soup.select("a")


for i in range(num_iter):
    links.append(tClist[i].get_text())
        
links
#mw-content-text > div.mw-parser-output > ul:nth-child(13) > li:nth-child(1) > a
# Out:
# ['Jump to content',
#  'Main page',
#  'Contents',
#  'Current events',
#  'Random article',
#  'About Wikipedia',
#  'Contact us',
#  'Donate',
#  'Help',
#  'Learn to edit',
#  'Community portal',
#  'Recent changes',
#  'Upload file',
#  '\n\n\n\n\n\n',
#  '\nSearch\n',
#  'Create account',
#  'Log in',
#  ' Create account',
#  ' Log in',
#  'learn more',
#  'Contributions',
#  'Talk',
#  '\n(Top)\n',
#  '\n\n1Snakes\n',
#  '\n\n2Computing\n',
#  '\n\n3People\n',
#  '\n\n4Roller coasters\n',
#  '\n\n5Vehicles\n',
#  '\n\n6Weaponry\n',
#  '\n\n7Other uses\n',
#  '\n\n8See also\n',
#  'Afrikaans',
#  'Alemannisch',
#  'العربية',
#  'Azərbaycanca',
#  'বাংলা',
#  'Беларуская',
#  'Български',
#  'Čeština',
#  'Dansk',
#  'Deutsch',
#  'Esperanto',
#  'Euskara',
#  'فارسی',
#  'Français',
#  '한국어',
#  'Hrvatski',
#  'Ido',
#  'Bahasa Indonesia',
#  'Interlingua',
#  'Íslenska',
#  'Italiano',
#  'עברית',
#  'ქართული',
#  'Kongo',
#  'Latina',
#  'Lëtzebuergesch',
#  'Magyar',
# ...

# %%
anchors = soup.find_all('a')
all_links = set()
for link in anchors:
    if(link.get('href') != '#'): 
        if 'Python' in link.get('href'):
            linkText = url+str(link.get('href'))
            all_links.add(link)
            print(linkText)
            
##first option
# Out:
# https://en.wikipedia.org/wiki/Python/w/index.php?title=Special:CreateAccount&returnto=Python
# https://en.wikipedia.org/wiki/Python/w/index.php?title=Special:UserLogin&returnto=Python
# https://en.wikipedia.org/wiki/Python/w/index.php?title=Special:CreateAccount&returnto=Python
# https://en.wikipedia.org/wiki/Python/w/index.php?title=Special:UserLogin&returnto=Python
# https://en.wikipedia.org/wiki/Pythonhttps://af.wikipedia.org/wiki/Python
# https://en.wikipedia.org/wiki/Pythonhttps://als.wikipedia.org/wiki/Python
# https://en.wikipedia.org/wiki/Pythonhttps://az.wikipedia.org/wiki/Python_(d%C9%99qiql%C9%99%C5%9Fdirm%C9%99)
# https://en.wikipedia.org/wiki/Pythonhttps://be.wikipedia.org/wiki/Python
# https://en.wikipedia.org/wiki/Pythonhttps://cs.wikipedia.org/wiki/Python_(rozcestn%C3%ADk)
# https://en.wikipedia.org/wiki/Pythonhttps://da.wikipedia.org/wiki/Python
# https://en.wikipedia.org/wiki/Pythonhttps://de.wikipedia.org/wiki/Python
# ...

# %%
#[i for i in iterations]

thislist = []

for i in links:
    start_at=  str(i) 
    if 'Python' in i:
        link = "https://en.wikipedia.org/wiki/" + start_at
        link = link.replace(' ', '_')
        thislist.append(link)
        
thislist

data = pd.DataFrame({
    'links': thislist})

## second way , not giving all but most are right

# %%
data
# Out:
#                                                 links
# 0                https://en.wikipedia.org/wiki/Python
# 1            https://en.wikipedia.org/wiki/Pythonidae
# 2        https://en.wikipedia.org/wiki/Python_(genus)
# 3    https://en.wikipedia.org/wiki/Python_(mythology)
# 4   https://en.wikipedia.org/wiki/Python_(programm...
# 5       https://en.wikipedia.org/wiki/Python_of_Aenus
# 6      https://en.wikipedia.org/wiki/Python_(painter)
# 7   https://en.wikipedia.org/wiki/Python_of_Byzantium
# 8      https://en.wikipedia.org/wiki/Python_of_Catana
# 9        https://en.wikipedia.org/wiki/Python_Anghelo
# 10    https://en.wikipedia.org/wiki/Python_(Efteling)
# 11  https://en.wikipedia.org/wiki/Python_(Busch_Ga...
# 12  https://en.wikipedia.org/wiki/Python_(Coney_Is...
# 13  https://en.wikipedia.org/wiki/Python_(automobi...
# 14  https://en.wikipedia.org/wiki/Python_(Ford_pro...
# 15     https://en.wikipedia.org/wiki/Python_(missile)
# ...
